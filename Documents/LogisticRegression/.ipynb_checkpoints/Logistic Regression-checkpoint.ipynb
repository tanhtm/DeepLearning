# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## 1. Definition

# %% [markdown]
# - Regression analysis (Predictive analysis)
# - The dependent variable is dichotomous (binary).
# - Target is categorical

# %% [markdown]
# <img src="images/img1.png">

# %% [markdown]
# ## 2.  Notations

# %% [markdown]
# ### Sizes:
#
# - m : number of examples in the dataset
# - $n_x$ : input size
# - $n_y$ : output size (or number of classes)
#
# ### Objects:
#
# - $X \in R^{n_x × m}$ is the input matrix
# - $x^{(i)} \in R^{n_x}$ is the $i^{th}$ example represented as a column vector
# - $x^{(i)}_j$ is the $j^{th}$ feature value of the $i^{th}$ traing example
# - $Y \in R^{n_y × m}$ is the label matrix
# - $y^{(i)} \in R^{n_y}$ is the output label for the $i^{th}$ example
# - $w \in R^{1 × n_x}$ is the weight
# - $b \in R$ is the bias

# %% [markdown]
# ## 3. Model fitting
# https://en.wikipedia.org/wiki/Logistic_regression
# ### Hypothesis
# The goal is to model the probability of a random variable $Y$ being 0 or 1 given experimental data
#
# $z = w^Tx + b$
#
# $\hat{y} = g(z)$
#
# Where g() is a **sigmoid function**.
#
# $g(z) = \frac{1}{1 + e^{-z}}$
#
# <img src="images/sigmod.svg">
#
# $\huge h_{w,b}(x) = \hat{y} = \frac{1}{1 + e^{-(w^Tx + b)}}$
#
# Predict y = 0 if $\hat{y} < 0.5$, in other words $w^Tx + b < 0$
#
# Predict y = 1 if $\hat{y} \geq 0.5$, in other words $w^Tx + b \geq 0$
#
# The goal is to model the probability of a random variable $Y$ being 0 or 1 given experimental data.
#
# $h_{w,b}(X) = Pr(Y = 1 | X; w; b)$
#
# $1 - h_{w,b}(X) = Pr(Y = 0| X; w; b)$
#
# If we attempt to model the probability that $Y$ is 0 or 1 with the function
# $\Pr(Y = y\mid X; w; b)=h_{w, b}(X)^{y}(1-h_{w, b}(X))^{(1-y)}$, we take our likelihood function assuming that all the observations in the sample are independently Bernoulli distributed.
# ${\begin{aligned}L(w,b \mid x)&=\Pr(Y\mid X; w; b )\\&=\prod _{i}^m \Pr(y^{(i)}\mid x^{(i)}; w; b )\\&=\prod _{i}^m h_{w, b }(x^{(i)})^{y^{(i)}}(1-h_{w, b}(x^{(i)}))^{(1-y^{(i)})}\end{aligned}}$
#
# Typically, the log likelihood is maximized with a normalizing factor $m^{-1}$
#
# $ m^{-1}\log L(w, b \mid x)=m^{-1}\sum _{i=1}^{m}\log \Pr( Y = y^{(i)}\mid x^{(i)}; w; b )$
#
# Let $J(w, b)$ is cost function.
#
# $\begin{aligned}J(w, b) &= - m^{-1} \log L(w, b \mid x) \\
#                         &= - m^{-1}\sum _{i=1}^{m}\log \Pr( Y = y^{(i)}\mid x^{(i)}; w; b )\\
#                         &= \frac{-1}{m} \sum^{m}_{i=1}{\left (y^{(i)}\log{h_{w,b}(x^{(i)})} + (1-y^{(i)})\log{(1 - h_{w,b}(x^{(i)})}\right )}\\
# \end{aligned}$
#
# which is minimized using optimization techniques such as gradient descent.

# %% [markdown]
# ### Cost function
#
# $ \large J(w,b) = \frac{-1}{m} \sum^{m}_{i=1}{\left (y^{(i)}\log{h_{w,b}(x^{(i)})} + (1-y^{(i)})\log{(1 - h_{w,b}(x^{(i)})}\right )}
# $

# %% [markdown]
# ### Batch Gradient Descent
# https://github.com/trekhleb/homemade-machine-learning/blob/master/homemade/logistic_regression/README.md
#
# Gradient descent is an iterative optimization algorithm for finding the minimum of a cost function described above. To find a local minimum of a function using gradient descent, one takes steps proportional to the negative of the gradient (or approximate gradient) of the function at the current point.
#
# Picture below illustrates the steps we take going down of the hill to find local minimum.
#
# <img src="images/gd1.png">
#
# The direction of the step is defined by derivative of the cost function in current point.
#
# <img src="images/gd2.png">
#
# Once we decided what direction we need to go we need to decide what the size of the step we need to take.
#
# <img src="images/gd3.png">
#
#
# **We need to simultaneously update $w, b$:**
#
# $ w := w - \alpha \frac{\partial{J}}{\partial{w}}$
#
# $ b := b - \alpha \frac{\partial{J}}{\partial{b}}$
#
#
# **Find $\frac{\partial{J}}{\partial{w}}$, $\frac{\partial{J}}{\partial{b}}$:**
#
#
# Let: $z^{(i)} = w^Tx^{(i)} + b$ with $z^(i) \in R$
#
# Let: $a^{(i)} = h_{w,b}(x^{(i)}) = \frac{1}{1 + e^{-z^{(i)}}}$ with $a^{(i)} \in R$
#
# $J(w, b) = \frac{-1}{m} \sum^{m}_{i=1}{\left (y^{(i)}\log{a^{(i)}} + (1-y^{(i)})\log{(1 - a^{(i)})}\right )} $ with $J \in R$
#
# $\frac{\partial{J}}{\partial{z^{(i)}}} = \frac{\partial{J}}{\partial{a^{(i)}}} \frac{\partial{a^{(i)}}}{\partial{z^{(i)}}}$
#
# $\frac{\partial{J}}{\partial{a^{(i)}}} = \frac{-1}{m} \sum_{i=1}^m \left ( \frac{y^{(i)}}{a^{(i)}} -  \frac{1 - y^{(i)}}{1 - a^{(i)}} \right )$
#
# $\frac{\partial{a^{(i)}}}{\partial{z^{(i)}}} = a^{(i)} (1 - a^{(i)})$
#
# $\begin{aligned}
# \frac{\partial{J}}{\partial{z^{(i)}}}
# &= \frac{-1}{m} \sum_{i=1}^m (1- a^{(i)})y^{(i)}  - a^{(i)}(1 - y^{(i)}) \\
# &= \frac{1}{m} \sum_{i=1}^m a^{(i)} - y^{(i)}
# \end{aligned}
# $
#
# $\begin{aligned}
# \frac{\partial{J}}{\partial{w}}
# &= \frac{\partial{J}}{\partial{z^{(i)}}} \frac{\partial{z^{(i)}}}{\partial{w}}\\
# &= \frac{1}{m} \sum_{i=1}^m ( a^{(i)} - y^{(i)})  x^{(i)}\\
# \end{aligned}$
#
# $\begin{aligned}
# \frac{\partial{J}}{\partial{b}}
# &= \frac{\partial{J}}{\partial{z^{(i)}}} \frac{\partial{z^{(i)}}}{\partial{b}}\\
# &= \frac{1}{m} \sum_{i=1}^m ( a^{(i)} - y^{(i)})\\
# \end{aligned}$
#
# Update $w, b$:
#
# $ w := w - \alpha \frac{1}{m} \sum_{i=1}^m ( a^{(i)} - y^{(i)})  x^{(i)}$
#
# $ b := b - \alpha \frac{1}{m} \sum_{i=1}^m ( a^{(i)} - y^{(i)})$
#
# $\alpha$ - the learning rate, the constant that defines the size of the gradient descent step

# %% [markdown]
# ## 4. Programming

# %% [markdown]
# ### 4.1 Import modules

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from lib_logistic import load_dataset, load_extra_datasets

# %% [markdown]
# ### 4.2 Read data

# %%
X, Y = load_dataset('dataset.csv')
m = X.shape[0]
print("Shape of Feature Matrix:", X.shape) 
print("Shape Label Vector:", Y.shape)
# Out:
# Shape of Feature Matrix: (2, 100)
# Shape Label Vector: (1, 100)

# %% [markdown]
# #### Visualize the given data

# %%
plt.scatter(X[0, :], X[1, :], c=Y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
n_x, m = X.shape
print('m =', m) 
print('n_x =', n_x)
# Out:
# m = 100
# n_x = 2

# %% [markdown]
# ### 4.3 Building modules

# %% [markdown]
# #### 4.3.1 Helper functions
#
# Sigmoid function:
#
# $sigmoid(z) = \frac{1}{1 + e^{-z}}$

# %%
# GRADED FUNCTION: sigmoid
def sigmoid(z):
    """
    Compute the sigmoid of z

    Arguments:
    z -- A scalar or numpy array of any size.

    Return:
    s -- sigmoid(z)
    """
    return 1 / (1 + np.exp(-z))

# %% [markdown]
# #### 4.3.2  Initializing parameters
# Initialize w as a vector of zero

# %%
# GRADED FUNCTION: initialize_with_zeros

def initialize_with_zeros(dim):
    """
    This function creates a vector of zeros of shape (dim, 1) for w and initializes b to 0.
    
    Argument:
    dim -- size of the w vector we want (or number of parameters in this case)
    
    Returns:
    w -- initialized vector of shape (dim, 1)
    b -- initialized scalar (corresponds to the bias)
    """
    
    w = np.zeros((dim,1))
    b = 0
    
    return w, b

def initialize_with_random(dim):
    """
    This function creates a vector of zeros of shape (dim, 1) for w and initializes b to 0.
    
    Argument:
    dim -- size of the w vector we want (or number of parameters in this case)
    
    Returns:
    w -- initialized vector of shape (dim, 1)
    b -- initialized scalar (corresponds to the bias)
    """
    np.random.seed(2)
    w = np.random.randn(dim,1) * 0.01
    b = 0
    
    return w, b

# %% [markdown]
# #### 4.3.3 Forward and Backward propagation
# Forward Propagation:
# - Get X
# - Compute $A = \sigma(w^T X + b) = (a^{(1)}, a^{(2)}, ..., a^{(m-1)}, a^{(m)})$
# - Calculate the cost function: $J = -\frac{1}{m}\sum_{i=1}^{m}y^{(i)}\log(a^{(i)})+(1-y^{(i)})\log(1-a^{(i)})$
#
# Here are the two formulas you will be using:
#
# $$ \frac{\partial J}{\partial w} = \frac{1}{m} \sum_{i=1}^m ( a^{(i)} - y^{(i)})  x^{(i)} = \frac{1}{m}X(A-Y)^T$$
# $$ \frac{\partial J}{\partial b} = \frac{1}{m} \sum_{i=1}^m (a^{(i)}-y^{(i)})$$

# %%
# GRADED FUNCTION: propagate

def propagate(w, b, X, Y):
    """
    Implement the cost function and its gradient for the propagation explained above

    Arguments:
    w -- weights, a numpy array of size (n_x, 1)
    b -- bias, a scalar
    X -- data of size (n_x, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat) of size (1, number of examples)

    Return:
    cost -- negative log-likelihood cost for logistic regression
    dw -- gradient of the loss with respect to w, thus same shape as w
    db -- gradient of the loss with respect to b, thus same shape as b
    
    """
    
    m = X.shape[1]
    
    # FORWARD PROPAGATION (FROM X TO COST)
    A = sigmoid(np.dot(w.T,X)+b)                                 # compute activation
    cost = -1/m * (np.dot(Y,np.log(A).T) + np.dot(1 - Y,np.log(1 - A).T))
    
    # BACKWARD PROPAGATION (TO FIND GRAD)
    dw = 1 / m * np.dot(X,(A - Y).T)
    db = 1 / m * np.sum((A - Y).T)

    assert(dw.shape == w.shape)
    assert(db.dtype == float)
    cost = np.squeeze(cost)
    assert(cost.shape == ())
    
    grads = {"dw": dw,
             "db": db}
    
    return grads, cost

# %% [markdown]
# #### 4.3.4 Optimization
#
# Update the parameters using gradient descent.

# %%
# GRADED FUNCTION: optimize

def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    """
    This function optimizes w and b by running a gradient descent algorithm
    
    Arguments:
    w -- weights, a numpy array of size (n_x, 1)
    b -- bias, a scalar
    X -- data of shape (n_x, number of examples)
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat), of shape (1, number of examples)
    num_iterations -- number of iterations of the optimization loop
    learning_rate -- learning rate of the gradient descent update rule
    print_cost -- True to print the loss every 100 steps
    
    Returns:
    params -- dictionary containing the weights w and bias b
    grads -- dictionary containing the gradients of the weights and bias with respect to the cost function
    costs -- list of all the costs computed during the optimization, this will be used to plot the learning curve.
    
    """
    
    costs = []
    
    for i in range(num_iterations):
        
        
        # Cost and gradient calculation
        grads, cost = propagate(w,b,X,Y)
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # update rule
        w = w - learning_rate * dw
        b = b - learning_rate * db
        
        # Record the costs
        if i % 100 == 0:
            costs.append(cost)
        if i % 1000 == 0:
            #Plotting
            plt.scatter(X[0, :], X[1, :], c=Y.ravel(), s=40, cmap=plt.cm.Spectral);
            plot_x = X[0,:]
            plot_y = -(X[0,:]*w[0][0] + b)/w[1][0]
            plt.plot(plot_x, plot_y)
            plt.show()
        # Print the cost every 100 training iterations
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    # plot the cost

    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return params, grads, costs

# %% [markdown]
# #### 4.3.5 Predict
#
# We are able to use w and b to predict the labels for a dataset X. Implement the `predict()` function. There are two steps to computing predictions:
#
# 1. Calculate $\hat{Y} = A = \sigma(w^T X + b)$
#
# 2. Convert the entries of a into 0 (if activation <= 0.5) or 1 (if activation > 0.5), stores the predictions in a vector `Y_prediction`. If you wish, you can use an `if`/`else` statement in a `for` loop (though there is also a way to vectorize this).

# %%
# GRADED FUNCTION: predict

def predict(w, b, X):
    '''
    Predict whether the label is 0 or 1 using learned logistic regression parameters (w, b)
    
    Arguments:
    w -- weights, a numpy array of size (n_x, 1)
    b -- bias, a scalar
    X -- data of size (n_x, number of examples)
    
    Returns:
    Y_prediction -- a numpy array (vector) containing all predictions (0/1) for the examples in X
    '''
    
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)
    
    # Compute vector "A" predicting the probabilities of a cat being present in the picture
    A = sigmoid(np.dot(w.T, X) + b)
    
    for i in range(A.shape[1]):
        
        # Convert probabilities A[0,i] to actual predictions p[0,i]
        if A[0,i] > 0.5:
            Y_prediction[0,i] = 1
        pass
    
    return Y_prediction

# %% [markdown]
# #### 4.3.6 Merge all functions into a model

# %%
# GRADED FUNCTION: model

def model(X_train, Y_train, init_zero = True,  num_iterations = 2000, learning_rate = 0.5, print_cost = False):
    """
    Builds the logistic regression model by calling the function you've implemented previously
    
    Arguments:
    X_train -- training set represented by a numpy array of shape (num_px * num_px * 3, m_train)
    Y_train -- training labels represented by a numpy array (vector) of shape (1, m_train)
    X_test -- test set represented by a numpy array of shape (num_px * num_px * 3, m_test)
    Y_test -- test labels represented by a numpy array (vector) of shape (1, m_test)
    num_iterations -- hyperparameter representing the number of iterations to optimize the parameters
    learning_rate -- hyperparameter representing the learning rate used in the update rule of optimize()
    print_cost -- Set to true to print the cost every 100 iterations
    
    Returns:
    d -- dictionary containing information about the model.
    """
    
    w, b = initialize_with_zeros(X_train.shape[0])
    if not init_zero:
        w, b = initialize_with_random(X_train.shape[0])

    # Gradient descent (≈ 1 line of code)
    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    
    # Retrieve parameters w and b from dictionary "parameters"
    w = parameters["w"]
    b = parameters["b"]
    
    # Predict
    Y_prediction_train = predict(w, b, X_train)

    # Print train Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))

    
    d = {"costs": costs,
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

# %% [markdown]
# ### 4.4 Traning data

# %%
d = model(X, Y,False, num_iterations = 100000, learning_rate = 0.001, print_cost = True)
# Out:
# Cost after iteration 0: 0.692346
# Cost after iteration 100: 0.685567
# Cost after iteration 200: 0.679145
# Cost after iteration 300: 0.672857
# Cost after iteration 400: 0.666672
# Cost after iteration 500: 0.660586
# Cost after iteration 600: 0.654597
# Cost after iteration 700: 0.648702
# Cost after iteration 800: 0.642900
# Cost after iteration 900: 0.637190
# Cost after iteration 1000: 0.631570
# Cost after iteration 1100: 0.626039
# Cost after iteration 1200: 0.620594
# Cost after iteration 1300: 0.615235
# Cost after iteration 1400: 0.609960
# Cost after iteration 1500: 0.604767
# Cost after iteration 1600: 0.599655
# Cost after iteration 1700: 0.594623
# Cost after iteration 1800: 0.589668
# Cost after iteration 1900: 0.584791
# Cost after iteration 2000: 0.579989
# Cost after iteration 2100: 0.575260
# Cost after iteration 2200: 0.570605
# Cost after iteration 2300: 0.566020
# Cost after iteration 2400: 0.561506
# Cost after iteration 2500: 0.557060
# Cost after iteration 2600: 0.552682
# Cost after iteration 2700: 0.548370
# Cost after iteration 2800: 0.544123
# Cost after iteration 2900: 0.539940
# Cost after iteration 3000: 0.535819
# Cost after iteration 3100: 0.531760
# Cost after iteration 3200: 0.527761
# Cost after iteration 3300: 0.523822
# Cost after iteration 3400: 0.519940
# Cost after iteration 3500: 0.516116
# Cost after iteration 3600: 0.512347
# Cost after iteration 3700: 0.508634
# Cost after iteration 3800: 0.504974
# Cost after iteration 3900: 0.501368
# Cost after iteration 4000: 0.497813
# Cost after iteration 4100: 0.494309
# Cost after iteration 4200: 0.490856
# Cost after iteration 4300: 0.487451
# Cost after iteration 4400: 0.484095
# Cost after iteration 4500: 0.480786
# Cost after iteration 4600: 0.477524
# Cost after iteration 4700: 0.474307
# Cost after iteration 4800: 0.471135
# Cost after iteration 4900: 0.468007
# Cost after iteration 5000: 0.464922
# Cost after iteration 5100: 0.461880
# Cost after iteration 5200: 0.458879
# Cost after iteration 5300: 0.455919
# Cost after iteration 5400: 0.453000
# Cost after iteration 5500: 0.450119
# Cost after iteration 5600: 0.447277
# Cost after iteration 5700: 0.444474
# Cost after iteration 5800: 0.441707
# Cost after iteration 5900: 0.438978
# Cost after iteration 6000: 0.436284
# Cost after iteration 6100: 0.433625
# Cost after iteration 6200: 0.431002
# Cost after iteration 6300: 0.428412
# Cost after iteration 6400: 0.425856
# Cost after iteration 6500: 0.423333
# Cost after iteration 6600: 0.420842
# Cost after iteration 6700: 0.418383
# Cost after iteration 6800: 0.415955
# Cost after iteration 6900: 0.413558
# Cost after iteration 7000: 0.411191
# Cost after iteration 7100: 0.408853
# Cost after iteration 7200: 0.406545
# Cost after iteration 7300: 0.404265
# Cost after iteration 7400: 0.402014
# Cost after iteration 7500: 0.399790
# Cost after iteration 7600: 0.397593
# Cost after iteration 7700: 0.395423
# Cost after iteration 7800: 0.393279
# Cost after iteration 7900: 0.391161
# Cost after iteration 8000: 0.389069
# Cost after iteration 8100: 0.387001
# Cost after iteration 8200: 0.384958
# Cost after iteration 8300: 0.382939
# Cost after iteration 8400: 0.380944
# Cost after iteration 8500: 0.378972
# Cost after iteration 8600: 0.377023
# Cost after iteration 8700: 0.375096
# Cost after iteration 8800: 0.373192
# Cost after iteration 8900: 0.371310
# Cost after iteration 9000: 0.369449
# Cost after iteration 9100: 0.367610
# Cost after iteration 9200: 0.365791
# Cost after iteration 9300: 0.363992
# Cost after iteration 9400: 0.362214
# Cost after iteration 9500: 0.360456
# Cost after iteration 9600: 0.358717
# Cost after iteration 9700: 0.356997
# Cost after iteration 9800: 0.355297
# Cost after iteration 9900: 0.353615
# Cost after iteration 10000: 0.351951
# Cost after iteration 10100: 0.350305
# Cost after iteration 10200: 0.348677
# Cost after iteration 10300: 0.347066
# Cost after iteration 10400: 0.345473
# Cost after iteration 10500: 0.343897
# Cost after iteration 10600: 0.342337
# Cost after iteration 10700: 0.340794
# Cost after iteration 10800: 0.339267
# Cost after iteration 10900: 0.337756
# Cost after iteration 11000: 0.336260
# Cost after iteration 11100: 0.334780
# Cost after iteration 11200: 0.333316
# Cost after iteration 11300: 0.331866
# Cost after iteration 11400: 0.330431
# Cost after iteration 11500: 0.329011
# Cost after iteration 11600: 0.327605
# Cost after iteration 11700: 0.326213
# Cost after iteration 11800: 0.324835
# Cost after iteration 11900: 0.323471
# Cost after iteration 12000: 0.322121
# Cost after iteration 12100: 0.320783
# Cost after iteration 12200: 0.319459
# Cost after iteration 12300: 0.318148
# Cost after iteration 12400: 0.316850
# Cost after iteration 12500: 0.315564
# Cost after iteration 12600: 0.314291
# Cost after iteration 12700: 0.313030
# Cost after iteration 12800: 0.311781
# Cost after iteration 12900: 0.310544
# Cost after iteration 13000: 0.309318
# Cost after iteration 13100: 0.308105
# Cost after iteration 13200: 0.306902
# Cost after iteration 13300: 0.305711
# Cost after iteration 13400: 0.304531
# Cost after iteration 13500: 0.303362
# Cost after iteration 13600: 0.302204
# Cost after iteration 13700: 0.301057
# Cost after iteration 13800: 0.299920
# Cost after iteration 13900: 0.298793
# Cost after iteration 14000: 0.297677
# Cost after iteration 14100: 0.296571
# Cost after iteration 14200: 0.295474
# Cost after iteration 14300: 0.294388
# Cost after iteration 14400: 0.293311
# Cost after iteration 14500: 0.292244
# Cost after iteration 14600: 0.291186
# Cost after iteration 14700: 0.290138
# Cost after iteration 14800: 0.289099
# Cost after iteration 14900: 0.288069
# Cost after iteration 15000: 0.287047
# Cost after iteration 15100: 0.286035
# Cost after iteration 15200: 0.285032
# Cost after iteration 15300: 0.284037
# Cost after iteration 15400: 0.283050
# Cost after iteration 15500: 0.282072
# Cost after iteration 15600: 0.281103
# Cost after iteration 15700: 0.280141
# Cost after iteration 15800: 0.279188
# Cost after iteration 15900: 0.278243
# Cost after iteration 16000: 0.277305
# Cost after iteration 16100: 0.276376
# Cost after iteration 16200: 0.275454
# Cost after iteration 16300: 0.274540
# Cost after iteration 16400: 0.273633
# Cost after iteration 16500: 0.272733
# Cost after iteration 16600: 0.271841
# Cost after iteration 16700: 0.270957
# Cost after iteration 16800: 0.270079
# Cost after iteration 16900: 0.269209
# Cost after iteration 17000: 0.268345
# Cost after iteration 17100: 0.267488
# Cost after iteration 17200: 0.266639
# Cost after iteration 17300: 0.265796
# Cost after iteration 17400: 0.264959
# Cost after iteration 17500: 0.264129
# Cost after iteration 17600: 0.263306
# Cost after iteration 17700: 0.262489
# Cost after iteration 17800: 0.261679
# Cost after iteration 17900: 0.260875
# Cost after iteration 18000: 0.260077
# Cost after iteration 18100: 0.259285
# Cost after iteration 18200: 0.258499
# Cost after iteration 18300: 0.257719
# Cost after iteration 18400: 0.256945
# Cost after iteration 18500: 0.256177
# Cost after iteration 18600: 0.255415
# Cost after iteration 18700: 0.254659
# Cost after iteration 18800: 0.253908
# Cost after iteration 18900: 0.253163
# Cost after iteration 19000: 0.252423
# Cost after iteration 19100: 0.251689
# Cost after iteration 19200: 0.250960
# Cost after iteration 19300: 0.250237
# Cost after iteration 19400: 0.249519
# Cost after iteration 19500: 0.248806
# Cost after iteration 19600: 0.248098
# Cost after iteration 19700: 0.247396
# Cost after iteration 19800: 0.246698
# Cost after iteration 19900: 0.246006
# Cost after iteration 20000: 0.245319
# Cost after iteration 20100: 0.244636
# Cost after iteration 20200: 0.243958
# Cost after iteration 20300: 0.243286
# Cost after iteration 20400: 0.242617
# Cost after iteration 20500: 0.241954
# Cost after iteration 20600: 0.241295
# Cost after iteration 20700: 0.240641
# Cost after iteration 20800: 0.239992
# Cost after iteration 20900: 0.239347
# Cost after iteration 21000: 0.238706
# Cost after iteration 21100: 0.238070
# Cost after iteration 21200: 0.237438
# Cost after iteration 21300: 0.236810
# Cost after iteration 21400: 0.236187
# Cost after iteration 21500: 0.235568
# Cost after iteration 21600: 0.234953
# Cost after iteration 21700: 0.234343
# Cost after iteration 21800: 0.233736
# Cost after iteration 21900: 0.233134
# Cost after iteration 22000: 0.232535
# Cost after iteration 22100: 0.231941
# Cost after iteration 22200: 0.231351
# Cost after iteration 22300: 0.230764
# Cost after iteration 22400: 0.230181
# Cost after iteration 22500: 0.229602
# Cost after iteration 22600: 0.229027
# Cost after iteration 22700: 0.228456
# Cost after iteration 22800: 0.227888
# Cost after iteration 22900: 0.227324
# Cost after iteration 23000: 0.226764
# Cost after iteration 23100: 0.226208
# Cost after iteration 23200: 0.225654
# Cost after iteration 23300: 0.225105
# Cost after iteration 23400: 0.224559
# Cost after iteration 23500: 0.224016
# Cost after iteration 23600: 0.223477
# Cost after iteration 23700: 0.222941
# Cost after iteration 23800: 0.222409
# Cost after iteration 23900: 0.221880
# Cost after iteration 24000: 0.221354
# Cost after iteration 24100: 0.220832
# Cost after iteration 24200: 0.220313
# Cost after iteration 24300: 0.219797
# Cost after iteration 24400: 0.219284
# Cost after iteration 24500: 0.218774
# Cost after iteration 24600: 0.218268
# Cost after iteration 24700: 0.217764
# Cost after iteration 24800: 0.217264
# Cost after iteration 24900: 0.216767
# Cost after iteration 25000: 0.216272
# Cost after iteration 25100: 0.215781
# Cost after iteration 25200: 0.215293
# Cost after iteration 25300: 0.214807
# Cost after iteration 25400: 0.214325
# Cost after iteration 25500: 0.213845
# Cost after iteration 25600: 0.213368
# Cost after iteration 25700: 0.212894
# Cost after iteration 25800: 0.212423
# Cost after iteration 25900: 0.211955
# Cost after iteration 26000: 0.211489
# Cost after iteration 26100: 0.211026
# Cost after iteration 26200: 0.210566
# Cost after iteration 26300: 0.210109
# Cost after iteration 26400: 0.209654
# Cost after iteration 26500: 0.209202
# Cost after iteration 26600: 0.208752
# Cost after iteration 26700: 0.208305
# Cost after iteration 26800: 0.207861
# Cost after iteration 26900: 0.207419
# Cost after iteration 27000: 0.206979
# Cost after iteration 27100: 0.206542
# Cost after iteration 27200: 0.206108
# Cost after iteration 27300: 0.205676
# Cost after iteration 27400: 0.205246
# Cost after iteration 27500: 0.204819
# Cost after iteration 27600: 0.204395
# Cost after iteration 27700: 0.203972
# Cost after iteration 27800: 0.203552
# Cost after iteration 27900: 0.203135
# Cost after iteration 28000: 0.202719
# Cost after iteration 28100: 0.202306
# Cost after iteration 28200: 0.201895
# Cost after iteration 28300: 0.201487
# Cost after iteration 28400: 0.201080
# Cost after iteration 28500: 0.200676
# Cost after iteration 28600: 0.200274
# Cost after iteration 28700: 0.199875
# Cost after iteration 28800: 0.199477
# Cost after iteration 28900: 0.199082
# Cost after iteration 29000: 0.198688
# Cost after iteration 29100: 0.198297
# Cost after iteration 29200: 0.197908
# Cost after iteration 29300: 0.197521
# Cost after iteration 29400: 0.197136
# Cost after iteration 29500: 0.196753
# Cost after iteration 29600: 0.196372
# Cost after iteration 29700: 0.195994
# Cost after iteration 29800: 0.195617
# Cost after iteration 29900: 0.195242
# Cost after iteration 30000: 0.194869
# Cost after iteration 30100: 0.194498
# Cost after iteration 30200: 0.194129
# Cost after iteration 30300: 0.193762
# Cost after iteration 30400: 0.193396
# Cost after iteration 30500: 0.193033
# Cost after iteration 30600: 0.192671
# Cost after iteration 30700: 0.192312
# Cost after iteration 30800: 0.191954
# Cost after iteration 30900: 0.191598
# Cost after iteration 31000: 0.191244
# Cost after iteration 31100: 0.190891
# Cost after iteration 31200: 0.190541
# Cost after iteration 31300: 0.190192
# Cost after iteration 31400: 0.189845
# Cost after iteration 31500: 0.189500
# Cost after iteration 31600: 0.189156
# Cost after iteration 31700: 0.188814
# Cost after iteration 31800: 0.188474
# Cost after iteration 31900: 0.188136
# Cost after iteration 32000: 0.187799
# Cost after iteration 32100: 0.187464
# Cost after iteration 32200: 0.187130
# Cost after iteration 32300: 0.186798
# Cost after iteration 32400: 0.186468
# Cost after iteration 32500: 0.186139
# Cost after iteration 32600: 0.185812
# Cost after iteration 32700: 0.185487
# Cost after iteration 32800: 0.185163
# Cost after iteration 32900: 0.184841
# Cost after iteration 33000: 0.184520
# Cost after iteration 33100: 0.184201
# Cost after iteration 33200: 0.183883
# Cost after iteration 33300: 0.183567
# Cost after iteration 33400: 0.183253
# Cost after iteration 33500: 0.182940
# Cost after iteration 33600: 0.182628
# Cost after iteration 33700: 0.182318
# Cost after iteration 33800: 0.182009
# Cost after iteration 33900: 0.181702
# Cost after iteration 34000: 0.181396
# Cost after iteration 34100: 0.181092
# Cost after iteration 34200: 0.180789
# Cost after iteration 34300: 0.180488
# Cost after iteration 34400: 0.180187
# Cost after iteration 34500: 0.179889
# Cost after iteration 34600: 0.179591
# Cost after iteration 34700: 0.179296
# Cost after iteration 34800: 0.179001
# Cost after iteration 34900: 0.178708
# Cost after iteration 35000: 0.178416
# Cost after iteration 35100: 0.178125
# Cost after iteration 35200: 0.177836
# Cost after iteration 35300: 0.177548
# Cost after iteration 35400: 0.177262
# Cost after iteration 35500: 0.176977
# Cost after iteration 35600: 0.176693
# Cost after iteration 35700: 0.176410
# Cost after iteration 35800: 0.176128
# Cost after iteration 35900: 0.175848
# Cost after iteration 36000: 0.175569
# Cost after iteration 36100: 0.175292
# Cost after iteration 36200: 0.175015
# Cost after iteration 36300: 0.174740
# Cost after iteration 36400: 0.174466
# Cost after iteration 36500: 0.174193
# Cost after iteration 36600: 0.173922
# Cost after iteration 36700: 0.173652
# Cost after iteration 36800: 0.173382
# Cost after iteration 36900: 0.173114
# Cost after iteration 37000: 0.172848
# Cost after iteration 37100: 0.172582
# Cost after iteration 37200: 0.172318
# Cost after iteration 37300: 0.172054
# Cost after iteration 37400: 0.171792
# Cost after iteration 37500: 0.171531
# Cost after iteration 37600: 0.171271
# Cost after iteration 37700: 0.171012
# Cost after iteration 37800: 0.170755
# Cost after iteration 37900: 0.170498
# Cost after iteration 38000: 0.170242
# Cost after iteration 38100: 0.169988
# Cost after iteration 38200: 0.169735
# Cost after iteration 38300: 0.169482
# Cost after iteration 38400: 0.169231
# Cost after iteration 38500: 0.168981
# Cost after iteration 38600: 0.168732
# Cost after iteration 38700: 0.168484
# Cost after iteration 38800: 0.168237
# Cost after iteration 38900: 0.167991
# Cost after iteration 39000: 0.167746
# Cost after iteration 39100: 0.167502
# Cost after iteration 39200: 0.167260
# Cost after iteration 39300: 0.167018
# Cost after iteration 39400: 0.166777
# Cost after iteration 39500: 0.166537
# Cost after iteration 39600: 0.166298
# Cost after iteration 39700: 0.166060
# Cost after iteration 39800: 0.165823
# Cost after iteration 39900: 0.165587
# Cost after iteration 40000: 0.165352
# Cost after iteration 40100: 0.165118
# Cost after iteration 40200: 0.164885
# Cost after iteration 40300: 0.164653
# Cost after iteration 40400: 0.164422
# Cost after iteration 40500: 0.164192
# Cost after iteration 40600: 0.163962
# Cost after iteration 40700: 0.163734
# Cost after iteration 40800: 0.163506
# Cost after iteration 40900: 0.163280
# Cost after iteration 41000: 0.163054
# Cost after iteration 41100: 0.162829
# Cost after iteration 41200: 0.162606
# Cost after iteration 41300: 0.162383
# Cost after iteration 41400: 0.162161
# Cost after iteration 41500: 0.161939
# Cost after iteration 41600: 0.161719
# Cost after iteration 41700: 0.161499
# Cost after iteration 41800: 0.161281
# Cost after iteration 41900: 0.161063
# Cost after iteration 42000: 0.160846
# Cost after iteration 42100: 0.160630
# Cost after iteration 42200: 0.160415
# Cost after iteration 42300: 0.160201
# Cost after iteration 42400: 0.159987
# Cost after iteration 42500: 0.159774
# Cost after iteration 42600: 0.159562
# Cost after iteration 42700: 0.159351
# Cost after iteration 42800: 0.159141
# Cost after iteration 42900: 0.158932
# Cost after iteration 43000: 0.158723
# Cost after iteration 43100: 0.158515
# Cost after iteration 43200: 0.158308
# Cost after iteration 43300: 0.158102
# Cost after iteration 43400: 0.157896
# Cost after iteration 43500: 0.157692
# Cost after iteration 43600: 0.157488
# Cost after iteration 43700: 0.157285
# Cost after iteration 43800: 0.157082
# Cost after iteration 43900: 0.156880
# Cost after iteration 44000: 0.156680
# Cost after iteration 44100: 0.156479
# Cost after iteration 44200: 0.156280
# Cost after iteration 44300: 0.156081
# Cost after iteration 44400: 0.155884
# Cost after iteration 44500: 0.155686
# Cost after iteration 44600: 0.155490
# Cost after iteration 44700: 0.155294
# Cost after iteration 44800: 0.155099
# Cost after iteration 44900: 0.154905
# Cost after iteration 45000: 0.154712
# Cost after iteration 45100: 0.154519
# Cost after iteration 45200: 0.154327
# Cost after iteration 45300: 0.154135
# Cost after iteration 45400: 0.153944
# Cost after iteration 45500: 0.153754
# Cost after iteration 45600: 0.153565
# Cost after iteration 45700: 0.153376
# Cost after iteration 45800: 0.153189
# Cost after iteration 45900: 0.153001
# Cost after iteration 46000: 0.152815
# Cost after iteration 46100: 0.152629
# Cost after iteration 46200: 0.152443
# Cost after iteration 46300: 0.152259
# Cost after iteration 46400: 0.152075
# Cost after iteration 46500: 0.151892
# Cost after iteration 46600: 0.151709
# Cost after iteration 46700: 0.151527
# Cost after iteration 46800: 0.151346
# Cost after iteration 46900: 0.151165
# Cost after iteration 47000: 0.150985
# Cost after iteration 47100: 0.150805
# Cost after iteration 47200: 0.150627
# Cost after iteration 47300: 0.150449
# Cost after iteration 47400: 0.150271
# Cost after iteration 47500: 0.150094
# Cost after iteration 47600: 0.149918
# Cost after iteration 47700: 0.149742
# Cost after iteration 47800: 0.149567
# Cost after iteration 47900: 0.149393
# Cost after iteration 48000: 0.149219
# Cost after iteration 48100: 0.149046
# Cost after iteration 48200: 0.148873
# Cost after iteration 48300: 0.148701
# Cost after iteration 48400: 0.148529
# Cost after iteration 48500: 0.148359
# Cost after iteration 48600: 0.148188
# Cost after iteration 48700: 0.148019
# Cost after iteration 48800: 0.147849
# Cost after iteration 48900: 0.147681
# Cost after iteration 49000: 0.147513
# Cost after iteration 49100: 0.147346
# Cost after iteration 49200: 0.147179
# Cost after iteration 49300: 0.147012
# Cost after iteration 49400: 0.146847
# Cost after iteration 49500: 0.146682
# Cost after iteration 49600: 0.146517
# Cost after iteration 49700: 0.146353
# Cost after iteration 49800: 0.146190
# Cost after iteration 49900: 0.146027
# Cost after iteration 50000: 0.145864
# Cost after iteration 50100: 0.145702
# Cost after iteration 50200: 0.145541
# Cost after iteration 50300: 0.145380
# Cost after iteration 50400: 0.145220
# Cost after iteration 50500: 0.145060
# Cost after iteration 50600: 0.144901
# Cost after iteration 50700: 0.144743
# Cost after iteration 50800: 0.144584
# Cost after iteration 50900: 0.144427
# Cost after iteration 51000: 0.144270
# Cost after iteration 51100: 0.144113
# Cost after iteration 51200: 0.143957
# Cost after iteration 51300: 0.143802
# Cost after iteration 51400: 0.143647
# Cost after iteration 51500: 0.143492
# Cost after iteration 51600: 0.143338
# Cost after iteration 51700: 0.143184
# Cost after iteration 51800: 0.143031
# Cost after iteration 51900: 0.142879
# Cost after iteration 52000: 0.142727
# Cost after iteration 52100: 0.142575
# Cost after iteration 52200: 0.142424
# Cost after iteration 52300: 0.142274
# Cost after iteration 52400: 0.142123
# Cost after iteration 52500: 0.141974
# Cost after iteration 52600: 0.141825
# Cost after iteration 52700: 0.141676
# Cost after iteration 52800: 0.141528
# Cost after iteration 52900: 0.141380
# Cost after iteration 53000: 0.141233
# Cost after iteration 53100: 0.141086
# Cost after iteration 53200: 0.140940
# Cost after iteration 53300: 0.140794
# Cost after iteration 53400: 0.140648
# Cost after iteration 53500: 0.140503
# Cost after iteration 53600: 0.140359
# Cost after iteration 53700: 0.140215
# Cost after iteration 53800: 0.140071
# Cost after iteration 53900: 0.139928
# Cost after iteration 54000: 0.139785
# Cost after iteration 54100: 0.139643
# Cost after iteration 54200: 0.139501
# Cost after iteration 54300: 0.139360
# Cost after iteration 54400: 0.139219
# Cost after iteration 54500: 0.139079
# Cost after iteration 54600: 0.138939
# Cost after iteration 54700: 0.138799
# Cost after iteration 54800: 0.138660
# Cost after iteration 54900: 0.138521
# Cost after iteration 55000: 0.138383
# Cost after iteration 55100: 0.138245
# Cost after iteration 55200: 0.138107
# Cost after iteration 55300: 0.137970
# Cost after iteration 55400: 0.137833
# Cost after iteration 55500: 0.137697
# Cost after iteration 55600: 0.137561
# Cost after iteration 55700: 0.137426
# Cost after iteration 55800: 0.137291
# Cost after iteration 55900: 0.137156
# Cost after iteration 56000: 0.137022
# Cost after iteration 56100: 0.136888
# Cost after iteration 56200: 0.136755
# Cost after iteration 56300: 0.136622
# Cost after iteration 56400: 0.136489
# Cost after iteration 56500: 0.136357
# Cost after iteration 56600: 0.136225
# Cost after iteration 56700: 0.136094
# Cost after iteration 56800: 0.135963
# Cost after iteration 56900: 0.135832
# Cost after iteration 57000: 0.135702
# Cost after iteration 57100: 0.135572
# Cost after iteration 57200: 0.135442
# Cost after iteration 57300: 0.135313
# Cost after iteration 57400: 0.135185
# Cost after iteration 57500: 0.135056
# Cost after iteration 57600: 0.134928
# Cost after iteration 57700: 0.134801
# Cost after iteration 57800: 0.134673
# Cost after iteration 57900: 0.134547
# Cost after iteration 58000: 0.134420
# Cost after iteration 58100: 0.134294
# Cost after iteration 58200: 0.134168
# Cost after iteration 58300: 0.134043
# Cost after iteration 58400: 0.133918
# Cost after iteration 58500: 0.133793
# Cost after iteration 58600: 0.133669
# Cost after iteration 58700: 0.133545
# Cost after iteration 58800: 0.133421
# Cost after iteration 58900: 0.133298
# Cost after iteration 59000: 0.133175
# Cost after iteration 59100: 0.133053
# Cost after iteration 59200: 0.132931
# Cost after iteration 59300: 0.132809
# Cost after iteration 59400: 0.132687
# Cost after iteration 59500: 0.132566
# Cost after iteration 59600: 0.132445
# Cost after iteration 59700: 0.132325
# Cost after iteration 59800: 0.132205
# Cost after iteration 59900: 0.132085
# Cost after iteration 60000: 0.131966
# Cost after iteration 60100: 0.131847
# Cost after iteration 60200: 0.131728
# Cost after iteration 60300: 0.131610
# Cost after iteration 60400: 0.131491
# Cost after iteration 60500: 0.131374
# Cost after iteration 60600: 0.131256
# Cost after iteration 60700: 0.131139
# Cost after iteration 60800: 0.131022
# Cost after iteration 60900: 0.130906
# Cost after iteration 61000: 0.130790
# Cost after iteration 61100: 0.130674
# Cost after iteration 61200: 0.130559
# Cost after iteration 61300: 0.130443
# Cost after iteration 61400: 0.130329
# Cost after iteration 61500: 0.130214
# Cost after iteration 61600: 0.130100
# Cost after iteration 61700: 0.129986
# Cost after iteration 61800: 0.129872
# Cost after iteration 61900: 0.129759
# Cost after iteration 62000: 0.129646
# Cost after iteration 62100: 0.129534
# Cost after iteration 62200: 0.129421
# Cost after iteration 62300: 0.129309
# Cost after iteration 62400: 0.129198
# Cost after iteration 62500: 0.129086
# Cost after iteration 62600: 0.128975
# Cost after iteration 62700: 0.128864
# Cost after iteration 62800: 0.128754
# Cost after iteration 62900: 0.128643
# Cost after iteration 63000: 0.128534
# Cost after iteration 63100: 0.128424
# Cost after iteration 63200: 0.128315
# Cost after iteration 63300: 0.128206
# Cost after iteration 63400: 0.128097
# Cost after iteration 63500: 0.127988
# Cost after iteration 63600: 0.127880
# Cost after iteration 63700: 0.127772
# Cost after iteration 63800: 0.127665
# Cost after iteration 63900: 0.127558
# Cost after iteration 64000: 0.127451
# Cost after iteration 64100: 0.127344
# Cost after iteration 64200: 0.127237
# Cost after iteration 64300: 0.127131
# Cost after iteration 64400: 0.127025
# Cost after iteration 64500: 0.126920
# Cost after iteration 64600: 0.126814
# Cost after iteration 64700: 0.126709
# Cost after iteration 64800: 0.126605
# Cost after iteration 64900: 0.126500
# Cost after iteration 65000: 0.126396
# Cost after iteration 65100: 0.126292
# Cost after iteration 65200: 0.126188
# Cost after iteration 65300: 0.126085
# Cost after iteration 65400: 0.125982
# Cost after iteration 65500: 0.125879
# Cost after iteration 65600: 0.125776
# Cost after iteration 65700: 0.125674
# Cost after iteration 65800: 0.125572
# Cost after iteration 65900: 0.125470
# Cost after iteration 66000: 0.125369
# Cost after iteration 66100: 0.125267
# Cost after iteration 66200: 0.125166
# Cost after iteration 66300: 0.125066
# Cost after iteration 66400: 0.124965
# Cost after iteration 66500: 0.124865
# Cost after iteration 66600: 0.124765
# Cost after iteration 66700: 0.124665
# Cost after iteration 66800: 0.124566
# Cost after iteration 66900: 0.124466
# Cost after iteration 67000: 0.124367
# Cost after iteration 67100: 0.124269
# Cost after iteration 67200: 0.124170
# Cost after iteration 67300: 0.124072
# Cost after iteration 67400: 0.123974
# Cost after iteration 67500: 0.123876
# Cost after iteration 67600: 0.123779
# Cost after iteration 67700: 0.123682
# Cost after iteration 67800: 0.123585
# Cost after iteration 67900: 0.123488
# Cost after iteration 68000: 0.123392
# Cost after iteration 68100: 0.123295
# Cost after iteration 68200: 0.123199
# Cost after iteration 68300: 0.123103
# Cost after iteration 68400: 0.123008
# Cost after iteration 68500: 0.122913
# Cost after iteration 68600: 0.122818
# Cost after iteration 68700: 0.122723
# Cost after iteration 68800: 0.122628
# Cost after iteration 68900: 0.122534
# Cost after iteration 69000: 0.122440
# Cost after iteration 69100: 0.122346
# Cost after iteration 69200: 0.122252
# Cost after iteration 69300: 0.122159
# Cost after iteration 69400: 0.122066
# Cost after iteration 69500: 0.121973
# Cost after iteration 69600: 0.121880
# Cost after iteration 69700: 0.121787
# Cost after iteration 69800: 0.121695
# Cost after iteration 69900: 0.121603
# Cost after iteration 70000: 0.121511
# Cost after iteration 70100: 0.121420
# Cost after iteration 70200: 0.121328
# Cost after iteration 70300: 0.121237
# Cost after iteration 70400: 0.121146
# Cost after iteration 70500: 0.121056
# Cost after iteration 70600: 0.120965
# Cost after iteration 70700: 0.120875
# Cost after iteration 70800: 0.120785
# Cost after iteration 70900: 0.120695
# Cost after iteration 71000: 0.120605
# Cost after iteration 71100: 0.120516
# Cost after iteration 71200: 0.120427
# Cost after iteration 71300: 0.120338
# Cost after iteration 71400: 0.120249
# Cost after iteration 71500: 0.120160
# Cost after iteration 71600: 0.120072
# Cost after iteration 71700: 0.119984
# Cost after iteration 71800: 0.119896
# Cost after iteration 71900: 0.119808
# Cost after iteration 72000: 0.119721
# Cost after iteration 72100: 0.119634
# Cost after iteration 72200: 0.119547
# Cost after iteration 72300: 0.119460
# Cost after iteration 72400: 0.119373
# Cost after iteration 72500: 0.119287
# Cost after iteration 72600: 0.119200
# Cost after iteration 72700: 0.119114
# Cost after iteration 72800: 0.119028
# Cost after iteration 72900: 0.118943
# Cost after iteration 73000: 0.118857
# Cost after iteration 73100: 0.118772
# Cost after iteration 73200: 0.118687
# Cost after iteration 73300: 0.118602
# Cost after iteration 73400: 0.118517
# Cost after iteration 73500: 0.118433
# Cost after iteration 73600: 0.118349
# Cost after iteration 73700: 0.118265
# Cost after iteration 73800: 0.118181
# Cost after iteration 73900: 0.118097
# Cost after iteration 74000: 0.118014
# Cost after iteration 74100: 0.117930
# Cost after iteration 74200: 0.117847
# Cost after iteration 74300: 0.117764
# Cost after iteration 74400: 0.117682
# Cost after iteration 74500: 0.117599
# Cost after iteration 74600: 0.117517
# Cost after iteration 74700: 0.117435
# Cost after iteration 74800: 0.117353
# Cost after iteration 74900: 0.117271
# Cost after iteration 75000: 0.117189
# Cost after iteration 75100: 0.117108
# Cost after iteration 75200: 0.117027
# Cost after iteration 75300: 0.116946
# Cost after iteration 75400: 0.116865
# Cost after iteration 75500: 0.116784
# Cost after iteration 75600: 0.116704
# Cost after iteration 75700: 0.116624
# Cost after iteration 75800: 0.116544
# Cost after iteration 75900: 0.116464
# Cost after iteration 76000: 0.116384
# Cost after iteration 76100: 0.116304
# Cost after iteration 76200: 0.116225
# Cost after iteration 76300: 0.116146
# Cost after iteration 76400: 0.116067
# Cost after iteration 76500: 0.115988
# Cost after iteration 76600: 0.115909
# Cost after iteration 76700: 0.115831
# Cost after iteration 76800: 0.115752
# Cost after iteration 76900: 0.115674
# Cost after iteration 77000: 0.115596
# Cost after iteration 77100: 0.115518
# Cost after iteration 77200: 0.115441
# Cost after iteration 77300: 0.115363
# Cost after iteration 77400: 0.115286
# Cost after iteration 77500: 0.115209
# Cost after iteration 77600: 0.115132
# Cost after iteration 77700: 0.115055
# Cost after iteration 77800: 0.114979
# Cost after iteration 77900: 0.114902
# Cost after iteration 78000: 0.114826
# Cost after iteration 78100: 0.114750
# Cost after iteration 78200: 0.114674
# Cost after iteration 78300: 0.114598
# Cost after iteration 78400: 0.114523
# Cost after iteration 78500: 0.114447
# Cost after iteration 78600: 0.114372
# Cost after iteration 78700: 0.114297
# Cost after iteration 78800: 0.114222
# Cost after iteration 78900: 0.114147
# Cost after iteration 79000: 0.114073
# Cost after iteration 79100: 0.113998
# Cost after iteration 79200: 0.113924
# Cost after iteration 79300: 0.113850
# Cost after iteration 79400: 0.113776
# Cost after iteration 79500: 0.113702
# Cost after iteration 79600: 0.113628
# Cost after iteration 79700: 0.113555
# Cost after iteration 79800: 0.113482
# Cost after iteration 79900: 0.113409
# Cost after iteration 80000: 0.113336
# Cost after iteration 80100: 0.113263
# Cost after iteration 80200: 0.113190
# Cost after iteration 80300: 0.113117
# Cost after iteration 80400: 0.113045
# Cost after iteration 80500: 0.112973
# Cost after iteration 80600: 0.112901
# Cost after iteration 80700: 0.112829
# Cost after iteration 80800: 0.112757
# Cost after iteration 80900: 0.112685
# Cost after iteration 81000: 0.112614
# Cost after iteration 81100: 0.112543
# Cost after iteration 81200: 0.112472
# Cost after iteration 81300: 0.112401
# Cost after iteration 81400: 0.112330
# Cost after iteration 81500: 0.112259
# Cost after iteration 81600: 0.112188
# Cost after iteration 81700: 0.112118
# Cost after iteration 81800: 0.112048
# Cost after iteration 81900: 0.111978
# Cost after iteration 82000: 0.111908
# Cost after iteration 82100: 0.111838
# Cost after iteration 82200: 0.111768
# Cost after iteration 82300: 0.111699
# Cost after iteration 82400: 0.111629
# Cost after iteration 82500: 0.111560
# Cost after iteration 82600: 0.111491
# Cost after iteration 82700: 0.111422
# Cost after iteration 82800: 0.111353
# Cost after iteration 82900: 0.111285
# Cost after iteration 83000: 0.111216
# Cost after iteration 83100: 0.111148
# Cost after iteration 83200: 0.111080
# Cost after iteration 83300: 0.111011
# Cost after iteration 83400: 0.110944
# Cost after iteration 83500: 0.110876
# Cost after iteration 83600: 0.110808
# Cost after iteration 83700: 0.110741
# Cost after iteration 83800: 0.110673
# Cost after iteration 83900: 0.110606
# Cost after iteration 84000: 0.110539
# Cost after iteration 84100: 0.110472
# Cost after iteration 84200: 0.110405
# Cost after iteration 84300: 0.110338
# Cost after iteration 84400: 0.110272
# Cost after iteration 84500: 0.110205
# Cost after iteration 84600: 0.110139
# Cost after iteration 84700: 0.110073
# Cost after iteration 84800: 0.110007
# Cost after iteration 84900: 0.109941
# Cost after iteration 85000: 0.109875
# Cost after iteration 85100: 0.109810
# Cost after iteration 85200: 0.109744
# Cost after iteration 85300: 0.109679
# Cost after iteration 85400: 0.109613
# Cost after iteration 85500: 0.109548
# Cost after iteration 85600: 0.109483
# Cost after iteration 85700: 0.109419
# Cost after iteration 85800: 0.109354
# Cost after iteration 85900: 0.109289
# Cost after iteration 86000: 0.109225
# Cost after iteration 86100: 0.109161
# Cost after iteration 86200: 0.109096
# Cost after iteration 86300: 0.109032
# Cost after iteration 86400: 0.108968
# Cost after iteration 86500: 0.108905
# Cost after iteration 86600: 0.108841
# Cost after iteration 86700: 0.108777
# Cost after iteration 86800: 0.108714
# Cost after iteration 86900: 0.108651
# Cost after iteration 87000: 0.108588
# Cost after iteration 87100: 0.108525
# Cost after iteration 87200: 0.108462
# Cost after iteration 87300: 0.108399
# Cost after iteration 87400: 0.108336
# Cost after iteration 87500: 0.108274
# Cost after iteration 87600: 0.108211
# Cost after iteration 87700: 0.108149
# Cost after iteration 87800: 0.108087
# Cost after iteration 87900: 0.108025
# Cost after iteration 88000: 0.107963
# Cost after iteration 88100: 0.107901
# Cost after iteration 88200: 0.107839
# Cost after iteration 88300: 0.107778
# Cost after iteration 88400: 0.107716
# Cost after iteration 88500: 0.107655
# Cost after iteration 88600: 0.107594
# Cost after iteration 88700: 0.107533
# Cost after iteration 88800: 0.107472
# Cost after iteration 88900: 0.107411
# Cost after iteration 89000: 0.107350
# Cost after iteration 89100: 0.107289
# Cost after iteration 89200: 0.107229
# Cost after iteration 89300: 0.107169
# Cost after iteration 89400: 0.107108
# Cost after iteration 89500: 0.107048
# Cost after iteration 89600: 0.106988
# Cost after iteration 89700: 0.106928
# Cost after iteration 89800: 0.106868
# Cost after iteration 89900: 0.106809
# Cost after iteration 90000: 0.106749
# Cost after iteration 90100: 0.106690
# Cost after iteration 90200: 0.106630
# Cost after iteration 90300: 0.106571
# Cost after iteration 90400: 0.106512
# Cost after iteration 90500: 0.106453
# Cost after iteration 90600: 0.106394
# Cost after iteration 90700: 0.106335
# Cost after iteration 90800: 0.106277
# Cost after iteration 90900: 0.106218
# Cost after iteration 91000: 0.106160
# Cost after iteration 91100: 0.106101
# Cost after iteration 91200: 0.106043
# Cost after iteration 91300: 0.105985
# Cost after iteration 91400: 0.105927
# Cost after iteration 91500: 0.105869
# Cost after iteration 91600: 0.105811
# Cost after iteration 91700: 0.105754
# Cost after iteration 91800: 0.105696
# Cost after iteration 91900: 0.105639
# Cost after iteration 92000: 0.105581
# Cost after iteration 92100: 0.105524
# Cost after iteration 92200: 0.105467
# Cost after iteration 92300: 0.105410
# Cost after iteration 92400: 0.105353
# Cost after iteration 92500: 0.105296
# Cost after iteration 92600: 0.105240
# Cost after iteration 92700: 0.105183
# Cost after iteration 92800: 0.105127
# Cost after iteration 92900: 0.105070
# Cost after iteration 93000: 0.105014
# Cost after iteration 93100: 0.104958
# Cost after iteration 93200: 0.104902
# Cost after iteration 93300: 0.104846
# Cost after iteration 93400: 0.104790
# Cost after iteration 93500: 0.104734
# Cost after iteration 93600: 0.104678
# Cost after iteration 93700: 0.104623
# Cost after iteration 93800: 0.104567
# Cost after iteration 93900: 0.104512
# Cost after iteration 94000: 0.104457
# Cost after iteration 94100: 0.104402
# Cost after iteration 94200: 0.104347
# Cost after iteration 94300: 0.104292
# Cost after iteration 94400: 0.104237
# Cost after iteration 94500: 0.104182
# Cost after iteration 94600: 0.104127
# Cost after iteration 94700: 0.104073
# Cost after iteration 94800: 0.104018
# Cost after iteration 94900: 0.103964
# Cost after iteration 95000: 0.103910
# Cost after iteration 95100: 0.103856
# Cost after iteration 95200: 0.103802
# Cost after iteration 95300: 0.103748
# Cost after iteration 95400: 0.103694
# Cost after iteration 95500: 0.103640
# Cost after iteration 95600: 0.103586
# Cost after iteration 95700: 0.103533
# Cost after iteration 95800: 0.103479
# Cost after iteration 95900: 0.103426
# Cost after iteration 96000: 0.103373
# Cost after iteration 96100: 0.103320
# Cost after iteration 96200: 0.103267
# Cost after iteration 96300: 0.103214
# Cost after iteration 96400: 0.103161
# Cost after iteration 96500: 0.103108
# Cost after iteration 96600: 0.103055
# Cost after iteration 96700: 0.103003
# Cost after iteration 96800: 0.102950
# Cost after iteration 96900: 0.102898
# Cost after iteration 97000: 0.102845
# Cost after iteration 97100: 0.102793
# Cost after iteration 97200: 0.102741
# Cost after iteration 97300: 0.102689
# Cost after iteration 97400: 0.102637
# Cost after iteration 97500: 0.102585
# Cost after iteration 97600: 0.102533
# Cost after iteration 97700: 0.102482
# Cost after iteration 97800: 0.102430
# Cost after iteration 97900: 0.102379
# Cost after iteration 98000: 0.102327
# Cost after iteration 98100: 0.102276
# Cost after iteration 98200: 0.102225
# Cost after iteration 98300: 0.102174
# Cost after iteration 98400: 0.102123
# Cost after iteration 98500: 0.102072
# Cost after iteration 98600: 0.102021
# Cost after iteration 98700: 0.101970
# Cost after iteration 98800: 0.101919
# Cost after iteration 98900: 0.101869
# Cost after iteration 99000: 0.101818
# Cost after iteration 99100: 0.101768
# Cost after iteration 99200: 0.101718
# Cost after iteration 99300: 0.101667
# Cost after iteration 99400: 0.101617
# Cost after iteration 99500: 0.101567
# Cost after iteration 99600: 0.101517
# Cost after iteration 99700: 0.101467
# Cost after iteration 99800: 0.101418
# Cost after iteration 99900: 0.101368
# train accuracy: 99.0 %

# %%
w = d['w']
b = d['b']
print("w= " + str(w))
print("b= " + str(b))
# Out:
# w= [[-3.04714588]
#  [ 5.10927801]]
# b= 0.7089356650397878

# %%
#Plotting
plt.scatter(X[0, :], X[1, :], c=Y.ravel(), s=40, cmap=plt.cm.Spectral);
plot_x = X[0,:]
plot_y = -(X[0,:]*w[0][0] + b)/w[1][0]
plt.plot(plot_x, plot_y)
plt.show()

# %% [markdown]
# ### 4.5 Performance on other datasets

# %%
X_, Y_ = load_dataset('dataset2.csv')
X_ = (X_ - np.mean(X_))/ np.std(X_) #normalizing

d_ = model(X_, Y_, num_iterations = 2000, learning_rate = 0.005, print_cost = True)
w = d_['w']
b = d_['b']
print(w, b)
plt.scatter(X_[0, :], X_[1, :], c=Y_.ravel(), s=40, cmap=plt.cm.Spectral);
plot_x = X_[0,:]
plot_y = -(X_[0,:]*w[0][0] + b)/w[1][0]
plt.plot(plot_x, plot_y);
# Out:
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.625411
# Cost after iteration 200: 0.572182
# Cost after iteration 300: 0.529903
# Cost after iteration 400: 0.495847
# Cost after iteration 500: 0.468003
# Cost after iteration 600: 0.444900
# Cost after iteration 700: 0.425467
# Cost after iteration 800: 0.408916
# Cost after iteration 900: 0.394658
# Cost after iteration 1000: 0.382251
# Cost after iteration 1100: 0.371357
# Cost after iteration 1200: 0.361713
# Cost after iteration 1300: 0.353113
# Cost after iteration 1400: 0.345395
# Cost after iteration 1500: 0.338427
# Cost after iteration 1600: 0.332102
# Cost after iteration 1700: 0.326334
# Cost after iteration 1800: 0.321050
# Cost after iteration 1900: 0.316190
# train accuracy: 89.0 %
# [[1.2737915 ]
#  [1.16518666]] 0.46829334898206904

# %%
# Datasets
noisy_circles, noisy_moons, blobs, gaussian_quantiles, no_structure = load_extra_datasets()

datasets = {"noisy_circles": noisy_circles,
            "noisy_moons": noisy_moons,
            "blobs": blobs,
            "gaussian_quantiles": gaussian_quantiles}

dataset = "gaussian_quantiles"

X, Y = datasets[dataset]
X, Y = X.T, Y.reshape(1, Y.shape[0])

# make blobs binary
if dataset == "blobs":
    Y = Y%2

# Visualize the data
plt.scatter(X[0, :], X[1, :], c=Y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
d = model(X, Y, num_iterations = 2000, learning_rate = 0.0003, print_cost = True)
w = d['w']
b = d['b']
plt.scatter(X[0, :], X[1, :], c=Y.ravel(), s=40, cmap=plt.cm.Spectral);
plot_x = X[0,:]
plot_y = -(X[0,:]*w[0][0] + b)/w[1][0]
plt.plot(plot_x, plot_y);
plt.xlabel('Feature 1') 
plt.ylabel('Feature 2') 
plt.title('Plot of given data')
plt.show()
# Out:
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.693101
# Cost after iteration 200: 0.693055
# Cost after iteration 300: 0.693010
# Cost after iteration 400: 0.692965
# Cost after iteration 500: 0.692920
# Cost after iteration 600: 0.692875
# Cost after iteration 700: 0.692831
# Cost after iteration 800: 0.692787
# Cost after iteration 900: 0.692744
# Cost after iteration 1000: 0.692700
# Cost after iteration 1100: 0.692657
# Cost after iteration 1200: 0.692614
# Cost after iteration 1300: 0.692572
# Cost after iteration 1400: 0.692530
# Cost after iteration 1500: 0.692488
# Cost after iteration 1600: 0.692446
# Cost after iteration 1700: 0.692405
# Cost after iteration 1800: 0.692364
# Cost after iteration 1900: 0.692323
# train accuracy: 55.0 %
